# %%
import pandas as pd

# %%
housing=pd.read_csv("india_housing_prices.csv", index_col=["ID"])

# %%
housing.head(2)
# Out:
#           State     City      Locality      Property_Type  BHK  Size_in_SqFt  \
# ID
# 1    Tamil Nadu  Chennai   Locality_84          Apartment    1          4740
# 2   Maharashtra     Pune  Locality_490  Independent House    3          2364
#
#     Price_in_Lakhs  Price_per_SqFt  Year_Built Furnished_Status  ...  \
# ID                                                               ...
# 1           489.76            0.10        1990        Furnished  ...
# 2           195.52            0.08        2008      Unfurnished  ...
#
#     Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# ID
# 1                35              10                 3
# 2                17               8                 1
#
#     Public_Transport_Accessibility  Parking_Space Security  \
# ID
# 1                             High             No       No
# 2                              Low             No      Yes
#
#                                    Amenities Facing Owner_Type  \
# ID
# ...

# %%
housing.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 1 to 250000
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   State                           250000 non-null  object
#  1   City                            250000 non-null  object
#  2   Locality                        250000 non-null  object
#  3   Property_Type                   250000 non-null  object
#  4   BHK                             250000 non-null  int64
#  5   Size_in_SqFt                    250000 non-null  int64
#  6   Price_in_Lakhs                  250000 non-null  float64
#  7   Price_per_SqFt                  250000 non-null  float64
#  8   Year_Built                      250000 non-null  int64
#  9   Furnished_Status                250000 non-null  object
#  10  Floor_No                        250000 non-null  int64
#  11  Total_Floors                    250000 non-null  int64
# ...

# %%
housing.shape
# Out:
# (250000, 22)

# %%
housing["Amenities"].str.split(",").values
# Out:
# array([list(['Playground', ' Gym', ' Garden', ' Pool', ' Clubhouse']),
#        list(['Playground', ' Clubhouse', ' Pool', ' Gym', ' Garden']),
#        list(['Clubhouse', ' Pool', ' Playground', ' Gym']), ...,
#        list(['Playground']), list(['Playground', ' Gym', ' Pool']),
#        list(['Gym', ' Garden'])], shape=(250000,), dtype=object)

# %%
from itertools import chain
merged = list(chain.from_iterable(housing["Amenities"].str.split(",").values))
merged = list(set(merged))
merged = set([item.strip() for item in merged])

# %%
merged
# Out:
# {'Clubhouse', 'Garden', 'Gym', 'Playground', 'Pool'}

# %%
housing["Amenities_value"]=housing["Amenities"].apply(lambda x: len(x.split(", ")))

# %%
housing["Amenities_value"]
# Out:
# ID
# 1         5
# 2         5
# 3         4
# 4         5
# 5         5
#          ..
# 249996    5
# 249997    1
# 249998    1
# 249999    3
# 250000    2
# Name: Amenities_value, Length: 250000, dtype: int64

# %%
housing["Amenities"].values[0]
# Out:
# 'Playground, Gym, Garden, Pool, Clubhouse'
